# %%
import pandas as pd

# %% [markdown]
# # Data Aggregation

# %% [markdown]
# In the first step, we aggregate the data from the German website: https://www.kohlenhydrate-tabellen.com/naehrwerttabelle/
#
# The data is stored in a csv-file and need to be cleaned before processing

# %%
df = pd.read_csv('Nährwerte.csv', sep=';', header=None)

# %%
df
# Out:
#                                                        0
# 0                                           Vollkornbrot
# 1      Energie       187,6 Kcal         Magnes.      ...
# 2      Wasser         44,0  g           Calcium      ...
# 3      Eiweiß          6,5  g           Phosph.      ...
# 4      Fett            1,0  g           Eisen        ...
# ...                                                  ...
# 15381  Harnsr.       130,6 mg           Fols.        ...
# 15382  tie. EW        14,9  g           Vit. B1      ...
# 15383  BST             1,0  g           Vit. B2      ...
# 15384  Natrium       154,3 mg           Vit. B6      ...
# 15385  Kalium        242,8 mg           Vit. C       ...
#
# [15386 rows x 1 columns]

# %% [markdown]
# List of all used foods in German

# %%
for i in range(0, len(df.index)):
    if ((i+14)%14)==0:
        print(df.iloc[i])
# Out:
# 0    Vollkornbrot
# Name: 0, dtype: object
# 0    Vollkornbrot mit Ölsamen
# Name: 14, dtype: object
# 0    Graubrot-Toastbrot mit Schrot
# Name: 28, dtype: object
# 0    Graubrot-Weizenmischbrot
# Name: 42, dtype: object
# 0    Graubrot-Mehrkornbrot
# Name: 56, dtype: object
# 0    Weißbrot-Toastbrot
# Name: 70, dtype: object
# 0    Weißbrot-Weizenbrot
# Name: 84, dtype: object
# 0    Vollkornbrötchen
# Name: 98, dtype: object
# 0    Vollkornbrötchen mit Ölsamen
# Name: 112, dtype: object
# 0    Brötchen
# Name: 126, dtype: object
# 0    Brötchen mit Ölsamen
# Name: 140, dtype: object
# 0    Brötchen-Roggenbrötchen
# Name: 154, dtype: object
# 0    Knäckebrot
# Name: 168, dtype: object
# 0    Grahambrot
# Name: 182, dtype: object
# 0    Pumpernickel
# Name: 196, dtype: object
# 0    Baguette
# Name: 210, dtype: object
# 0    Fladenbrote
# Name: 224, dtype: object
# 0    Paniermehl
# Name: 238, dtype: object
# 0    Getreide
# Name: 252, dtype: object
# 0    Weizen Vollkorn
# Name: 266, dtype: object
# 0    Weizen Keim
# Name: 280, dtype: object
# 0    Weizen Grieß
# Name: 294, dtype: object
# 0    Roggen Vollkorn
# Name: 308, dtype: object
# 0    Hafer ganzes Korn
# Name: 322, dtype: object
# 0    Hafer Flocken
# Name: 336, dtype: object
# 0    Gerste Vollkorn
# Name: 350, dtype: object
# 0    Gerste Perlgraupen
# Name: 364, dtype: object
# 0    Mehl
# Name: 378, dtype: object
# 0    Weizen Vollkornmehl
# Name: 392, dtype: object
# 0    Weizenmehl Typ 1050
# Name: 406, dtype: object
# 0    Weizen Feinmehl Typ 405
# Name: 420, dtype: object
# 0    Weizen Feinmehl Typ 550
# Name: 434, dtype: object
# 0    Weizen Kleie
# Name: 448, dtype: object
# 0    Roggen Vollkornmehl
# Name: 462, dtype: object
# 0    Roggenmehl Typ 1150
# Name: 476, dtype: object
# 0    Grünkern Vollkorn
# Name: 490, dtype: object
# 0    Buchweizen
# Name: 504, dtype: object
# 0    Hirse ganzes Korn
# Name: 518, dtype: object
# 0    Hirse Korn geschält
# Name: 532, dtype: object
# 0    Hirse Flocken
# Name: 546, dtype: object
# 0    Mais Vollkorn
# Name: 560, dtype: object
# 0    Mais Grieß
# Name: 574, dtype: object
# 0    Reis ungeschält
# Name: 588, dtype: object
# 0    Reis ungeschält gegart
# Name: 602, dtype: object
# 0    Reis geschält
# Name: 616, dtype: object
# 0    Reis geschält gegart
# Name: 630, dtype: object
# 0    Reis parboiled
# Name: 644, dtype: object
# 0    Reis parboiled gegart
# Name: 658, dtype: object
# 0    Mais Stärke
# Name: 672, dtype: object
# 0    Müsli
# Name: 686, dtype: object
# 0    Früchte-Müsli
# Name: 700, dtype: object
# 0    Müsli mit Trockenobst und Nüssen
# Name: 714, dtype: object
# 0    Cornflakes
# Name: 728, dtype: object
# 0    Reiscrispies
# Name: 742, dtype: object
# 0    Getreideflocken
# Name: 756, dtype: object
# 0    Mehrkornflocken mit Honig geröst
# Name: 770, dtype: object
# 0    Puffreis
# Name: 784, dtype: object
# 0    Puffreis mit Zucker/Honig geröst
# Name: 798, dtype: object
# 0    Puffmais (Popcorn)
# Name: 812, dtype: object
# 0    Laugengebäck
# Name: 826, dtype: object
# 0    Salzgebäck
# Name: 840, dtype: object
# 0    Zwieback
# Name: 854, dtype: object
# 0    Erdnußflips
# Name: 868, dtype: object
# 0    Kräcker
# Name: 882, dtype: object
# 0    Knabbergebäck
# Name: 896, dtype: object
# 0    Salzstangen
# Name: 910, dtype: object
# 0    Blätterteig
# Name: 924, dtype: object
# 0    Brandteig
# Name: 938, dtype: object
# 0    Hefeteig
# Name: 952, dtype: object
# 0    Mürbeteig
# Name: 966, dtype: object
# 0    Zwiebelkuchen
# Name: 980, dtype: object
# 0    Obstkuchen (allgemein)
# Name: 994, dtype: object
# 0    Obstkuchen mit Steinobst
# Name: 1008, dtype: object
# 0    Obstkuchen aus Rührmasse
# Name: 1022, dtype: object
# 0    Obstkuchen aus Hefeteig fettarm
# Name: 1036, dtype: object
# 0    Obstkuchen Mürbeteig fettreich
# Name: 1050, dtype: object
# 0    Torten
# Name: 1064, dtype: object
# 0    Cremetorte
# Name: 1078, dtype: object
# 0    Sachertorte
# Name: 1092, dtype: object
# 0    Käsesahnetorte
# Name: 1106, dtype: object
# 0    Linzertorte
# Name: 1120, dtype: object
# 0    Schwarzwälder Kirschtorte
# Name: 1134, dtype: object
# 0    Biskuitrolle
# Name: 1148, dtype: object
# 0    Buttercremetorte aus Biskuit
# Name: 1162, dtype: object
# 0    Biskuit-Obsttorte
# Name: 1176, dtype: object
# 0    Kuchen
# Name: 1190, dtype: object
# 0    Nußkuchen
# Name: 1204, dtype: object
# 0    Honigkuchen
# Name: 1218, dtype: object
# 0    Kuchen aus Rührmasse
# Name: 1232, dtype: object
# 0    Marmorkuchen aus Rührmasse
# Name: 1246, dtype: object
# 0    Donau-Wellen aus Rührmasse
# Name: 1260, dtype: object
# 0    Sandkuchen
# Name: 1274, dtype: object
# 0    Frankfurter Kranz aus Sandmasse
# Name: 1288, dtype: object
# 0    Kuchen (Hefeteig fettarm+Streusel)
# Name: 1302, dtype: object
# 0    Kuchen (Hefeteig fettarm+Rosinen)
# Name: 1316, dtype: object
# 0    Hefezopf aus Hefeteig fettarm
# Name: 1330, dtype: object
# 0    Gefüllter Kranz Hefeteig fettarm
# Name: 1344, dtype: object
# 0    Bienenstich Hefeteig fettreich
# Name: 1358, dtype: object
# 0    Napfkuchen (Gugelhupf)
# Name: 1372, dtype: object
# 0    Dresdner Stollen Hefet. fettreic
# Name: 1386, dtype: object
# 0    Marzipanstollen Hefeteig fettreich
# Name: 1400, dtype: object
# 0    Nußkranz aus Hefeteig fettreich
# Name: 1414, dtype: object
# 0    Mohnkranz aus Hefeteig fettreich
# Name: 1428, dtype: object
# 0    Käsekuchen aus Mürbeteig
# Name: 1442, dtype: object
# 0    Apfelstrudel
# Name: 1456, dtype: object
# 0    Quarkstrudel
# Name: 1470, dtype: object
# 0    Kleinteile aus besonderen Teigen
# Name: 1484, dtype: object
# 0    Baiser
# Name: 1498, dtype: object
# 0    Waffeln
# Name: 1512, dtype: object
# 0    Butterkeks
# Name: 1526, dtype: object
# 0    Lebkuchenteigbackwaren
# Name: 1540, dtype: object
# 0    Printen
# Name: 1554, dtype: object
# 0    Pfeffernüsse
# Name: 1568, dtype: object
# 0    Kokosmakronen
# Name: 1582, dtype: object
# 0    Baumkuchen
# Name: 1596, dtype: object
# 0    Plätzchen Kekse
# Name: 1610, dtype: object
# 0    Löffelbiskuit aus Biskuitmasse
# Name: 1624, dtype: object
# 0    Eclairs aus Brandmasse
# Name: 1638, dtype: object
# 0    Windbeutel mit Sahne
# Name: 1652, dtype: object
# 0    Plätzchen aus Mürbeteig
# Name: 1666, dtype: object
# 0    Spekulatius aus Mürbeteig
# Name: 1680, dtype: object
# 0    Obstpie (Boden, Deckel aus Mürbeteig)
# Name: 1694, dtype: object
# 0    Berliner aus Hefeteig fettarm
# Name: 1708, dtype: object
# 0    Nußhörnchen aus Hefeteig fettarm
# Name: 1722, dtype: object
# 0    Fettgebackenes (Hefeteig fettarm)
# Name: 1736, dtype: object
# 0    Schnecken aus Hefeteig fettarm
# Name: 1750, dtype: object
# 0    Croissant aus Blätterteig
# Name: 1764, dtype: object
# 0    Buntes Plundergebäck
# Name: 1778, dtype: object
# 0    Vollkornkeks
# Name: 1792, dtype: object
# 0    Obstkuchen Fertigmischung
# Name: 1806, dtype: object
# 0    Hühnerei frisch
# Name: 1820, dtype: object
# 0    Hühnerei frisch gegart
# Name: 1834, dtype: object
# 0    Hühnerei Eigelb
# Name: 1848, dtype: object
# 0    Hühnerei Eiweiß
# Name: 1862, dtype: object
# 0    Teigwaren (allgemein)
# Name: 1876, dtype: object
# 0    Teigwaren ohne Eier
# Name: 1890, dtype: object
# 0    Teigwaren eifrei gegart
# Name: 1904, dtype: object
# 0    Eierteigwaren
# Name: 1918, dtype: object
# 0    Eierteigwaren gegart
# Name: 1932, dtype: object
# 0    Vollkornteigwaren gegart
# Name: 1946, dtype: object
# 0    Vollkornteigwaren ohne Ei
# Name: 1960, dtype: object
# 0    Vollkorneierteigwaren
# Name: 1974, dtype: object
# 0    Nudelteig Nudelerzeugnis
# Name: 1988, dtype: object
# 0    Rhabarber frisch
# Name: 2002, dtype: object
# 0    Obstmischung frisch
# Name: 2016, dtype: object
# 0    Obstmischung getrocknet
# Name: 2030, dtype: object
# 0    Obstmischung Fruchtsaft
# Name: 2044, dtype: object
# 0    Obstmischung Fruchtnektar
# Name: 2058, dtype: object
# 0    Obstmischung Marmelade
# Name: 2072, dtype: object
# 0    Obstmischung Konserve
# Name: 2086, dtype: object
# 0    Apfel frisch
# Name: 2100, dtype: object
# 0    Apfel frisch ganz
# Name: 2114, dtype: object
# 0    Apfel frisch gegart
# Name: 2128, dtype: object
# 0    Apfel getrocknet
# Name: 2142, dtype: object
# 0    Apfel Fruchtsaft
# Name: 2156, dtype: object
# 0    Apfel Fruchtnektar
# Name: 2170, dtype: object
# 0    Apfel geschält frisch
# Name: 2184, dtype: object
# 0    Apfel geschält Konserve
# Name: 2198, dtype: object
# 0    Birne frisch
# Name: 2212, dtype: object
# 0    Birne frisch ganz
# Name: 2226, dtype: object
# 0    Birne frisch gegart
# Name: 2240, dtype: object
# 0    Birne Fruchtnektar
# Name: 2254, dtype: object
# 0    Birne Konserve
# Name: 2268, dtype: object
# 0    Quitte Marmelade
# Name: 2282, dtype: object
# 0    Aprikose frisch
# Name: 2296, dtype: object
# 0    Aprikose frisch gegart
# Name: 2310, dtype: object
# 0    Aprikose getrocknet
# Name: 2324, dtype: object
# 0    Aprikose Fruchtnektar
# Name: 2338, dtype: object
# 0    Aprikose Marmelade
# Name: 2352, dtype: object
# 0    Aprikose Konserve
# Name: 2366, dtype: object
# 0    Nektarine frisch
# Name: 2380, dtype: object
# 0    Pfirsich frisch
# Name: 2394, dtype: object
# 0    Pfirsich Fruchtnektar
# Name: 2408, dtype: object
# 0    Pfirsich Konserve
# Name: 2422, dtype: object
# 0    Süßkirsche frisch
# Name: 2436, dtype: object
# 0    Süßkirsche Marmelade
# Name: 2450, dtype: object
# 0    Süßkirsche Konserve
# Name: 2464, dtype: object
# 0    Sauerkirsche frisch
# Name: 2478, dtype: object
# 0    Sauerkirsche Fruchtsaft
# Name: 2492, dtype: object
# 0    Sauerkirsche Fruchtnektar
# Name: 2506, dtype: object
# 0    Sauerkirsche Marmelade
# Name: 2520, dtype: object
# 0    Sauerkirsche Konserve
# Name: 2534, dtype: object
# 0    Pflaumen frisch
# Name: 2548, dtype: object
# 0    Pflaumen getrocknet
# Name: 2562, dtype: object
# 0    Pflaumen Saft
# Name: 2576, dtype: object
# 0    Pflaumen Konserve, abgetropft
# Name: 2590, dtype: object
# 0    Zwetschge frisch
# Name: 2604, dtype: object
# 0    Mirabelle frisch
# Name: 2618, dtype: object
# 0    Mirabelle Marmelade
# Name: 2632, dtype: object
# 0    Mirabelle Konserve
# Name: 2646, dtype: object
# 0    Reineclaude frisch
# Name: 2660, dtype: object
# 0    Erdbeere frisch
# Name: 2674, dtype: object
# 0    Erdbeere Marmelade
# Name: 2688, dtype: object
# 0    Himbeere frisch
# Name: 2702, dtype: object
# 0    Himbeere Marmelade
# Name: 2716, dtype: object
# 0    Brombeere frisch
# Name: 2730, dtype: object
# 0    Brombeere Marmelade
# Name: 2744, dtype: object
# 0    Heidelbeere frisch
# Name: 2758, dtype: object
# 0    Heidelbeere Marmelade
# Name: 2772, dtype: object
# 0    Stachelbeere frisch
# Name: 2786, dtype: object
# 0    Stachelbeere Marmelade
# Name: 2800, dtype: object
# 0    Weintrauben frisch
# Name: 2814, dtype: object
# 0    Weintrauben getrocknet
# Name: 2828, dtype: object
# 0    Weintrauben Saft
# Name: 2842, dtype: object
# 0    Weintrauben Marmelade
# Name: 2856, dtype: object
# 0    Johannisbeere rot frisch
# Name: 2870, dtype: object
# 0    Johannisbeere rot Fruchtnektar
# Name: 2884, dtype: object
# 0    Johannisbeere rot Marmelade
# Name: 2898, dtype: object
# 0    Johannisbeere schwarz frisch
# Name: 2912, dtype: object
# 0    Johannisbeere schwarz Fruchtnektar
# Name: 2926, dtype: object
# 0    Johannisbeere schwarz Marmelade
# Name: 2940, dtype: object
# 0    Preiselbeere Marmelade
# Name: 2954, dtype: object
# 0    Hagebutte Konzentrat/Mark
# Name: 2968, dtype: object
# 0    Sanddornbeere Konzentrat
# Name: 2982, dtype: object
# 0    Holunderbeere frisch
# Name: 2996, dtype: object
# 0    Holunderbeere Fruchtsaft
# Name: 3010, dtype: object
# 0    Ananas frisch
# Name: 3024, dtype: object
# 0    Ananas Konserve
# Name: 3038, dtype: object
# 0    Avocado frisch
# Name: 3052, dtype: object
# 0    Banane frisch
# Name: 3066, dtype: object
# 0    Banane getrocknet
# Name: 3080, dtype: object
# 0    Dattel getrocknet
# Name: 3094, dtype: object
# 0    Feige frisch
# Name: 3108, dtype: object
# 0    Feige getrocknet
# Name: 3122, dtype: object
# 0    Granatapfel frisch
# Name: 3136, dtype: object
# 0    Kaki frisch
# Name: 3150, dtype: object
# 0    Passionsfrucht (Maracuja)
# Name: 3164, dtype: object
# 0    Passionsfrucht Fruchtsaft
# Name: 3178, dtype: object
# 0    Wassermelone frisch
# Name: 3192, dtype: object
# 0    Kiwi frisch
# Name: 3206, dtype: object
# 0    Kiwi Marmelade
# Name: 3220, dtype: object
# 0    Litchi Konserve
# Name: 3234, dtype: object
# 0    Mango frisch
# Name: 3248, dtype: object
# 0    Mango Konserve abgetropft
# Name: 3262, dtype: object
# 0    Papaya frisch
# Name: 3276, dtype: object
# 0    Zuckermelone frisch
# Name: 3290, dtype: object
# 0    Zitrone Fruchtsaft
# Name: 3304, dtype: object
# 0    Zitrone Marmelade
# Name: 3318, dtype: object
# 0    Orange frisch
# Name: 3332, dtype: object
# 0    Orange Fruchtsaft
# Name: 3346, dtype: object
# 0    Orange Fruchtnektar
# Name: 3360, dtype: object
# 0    Orange Marmelade
# Name: 3374, dtype: object
# 0    Grapefruit frisch
# Name: 3388, dtype: object
# 0    Grapefruit Fruchtsaft
# Name: 3402, dtype: object
# 0    Grapefruit Fruchtnektar
# Name: 3416, dtype: object
# 0    Mandarine frisch
# Name: 3430, dtype: object
# 0    Mandarine Konserve
# Name: 3444, dtype: object
# 0    Clementine frisch
# Name: 3458, dtype: object
# 0    Satsuma frisch
# Name: 3472, dtype: object
# 0    Rosinen
# Name: 3486, dtype: object
# 0    Sultaninen
# Name: 3500, dtype: object
# 0    Pflaumenmus
# Name: 3514, dtype: object
# 0    Algen frisch
# Name: 3528, dtype: object
# 0    Schnittlauch frisch
# Name: 3542, dtype: object
# 0    Kräutermischung
# Name: 3556, dtype: object
# 0    Gemüsemischung frisch gegart
# Name: 3570, dtype: object
# 0    Gemüsemischung Trunk
# Name: 3584, dtype: object
# 0    Suppengrün frisch
# Name: 3598, dtype: object
# 0    Chicoree frisch
# Name: 3612, dtype: object
# 0    Endivien frisch
# Name: 3626, dtype: object
# 0    Eisbergsalat frisch
# Name: 3640, dtype: object
# 0    Feldsalat frisch
# Name: 3654, dtype: object
# 0    Kopfsalat frisch
# Name: 3668, dtype: object
# 0    Radicchio frisch
# Name: 3682, dtype: object
# 0    Romanosalat frisch
# Name: 3696, dtype: object
# 0    Blattspinat gegart
# Name: 3710, dtype: object
# 0    Spinat tiefgefroren gegart
# Name: 3724, dtype: object
# 0    Blattspinat frisch
# Name: 3738, dtype: object
# 0    Bleichsellerie gegart
# Name: 3752, dtype: object
# 0    Bleichsellerie frisch
# Name: 3766, dtype: object
# 0    Sellerie frisch
# Name: 3780, dtype: object
# 0    Mangold frisch
# Name: 3794, dtype: object
# 0    Petersilienblatt frisch
# Name: 3808, dtype: object
# 0    Löwenzahn frisch
# Name: 3822, dtype: object
# 0    Sauerampfer frisch
# Name: 3836, dtype: object
# 0    Brunnenkresse frisch
# Name: 3850, dtype: object
# 0    Kresse frisch
# Name: 3864, dtype: object
# 0    Blumenkohl frisch
# Name: 3878, dtype: object
# 0    Blumenkohl frisch gegart
# Name: 3892, dtype: object
# 0    Broccoli frisch gegart
# Name: 3906, dtype: object
# 0    Chinakohl frisch
# Name: 3920, dtype: object
# 0    Chinakohl frisch gegart
# Name: 3934, dtype: object
# 0    Grünkohl frisch gegart
# Name: 3948, dtype: object
# 0    Grünkohl Konserve gegart
# Name: 3962, dtype: object
# 0    Kohlrabi frisch
# Name: 3976, dtype: object
# 0    Kohlrabi frisch gegart
# Name: 3990, dtype: object
# 0    Rosenkohl frisch gegart
# Name: 4004, dtype: object
# 0    Rotkohl frisch ganz
# Name: 4018, dtype: object
# 0    Rotkohl frisch gegart
# Name: 4032, dtype: object
# 0    Rotkohl Konserve gegart
# Name: 4046, dtype: object
# 0    Weißkohl frisch
# Name: 4060, dtype: object
# 0    Weißkohl frisch gegart
# Name: 4074, dtype: object
# 0    Wirsingkohl frisch gegart
# Name: 4088, dtype: object
# 0    Sauerkraut frisch gegart
# Name: 4102, dtype: object
# 0    Sauerkraut Konserve
# Name: 4116, dtype: object
# 0    Weinsauerkraut frisch
# Name: 4130, dtype: object
# 0    Artischockenboden Konserve
# Name: 4144, dtype: object
# 0    Fenchel frisch
# Name: 4158, dtype: object
# 0    Fenchel frisch gegart
# Name: 4172, dtype: object
# 0    Palmenherz Konserve gegart
# Name: 4186, dtype: object
# 0    Spargel frisch gegart
# Name: 4200, dtype: object
# 0    Spargel Konserve gegart
# Name: 4214, dtype: object
# 0    Portulak frisch
# Name: 4228, dtype: object
# 0    Porree frisch gegart
# Name: 4242, dtype: object
# 0    Zwiebeln frisch
# Name: 4256, dtype: object
# 0    Zwiebeln frisch gegart
# Name: 4270, dtype: object
# 0    Perlzwiebel Konserve, abgetropft
# Name: 4284, dtype: object
# 0    Schalotte frisch
# Name: 4298, dtype: object
# 0    Knoblauch frisch
# Name: 4312, dtype: object
# 0    Aubergine frisch gegart
# Name: 4326, dtype: object
# 0    Gurke frisch
# Name: 4340, dtype: object
# 0    Gurke frisch gegart
# Name: 4354, dtype: object
# 0    Paprikaschoten frisch gegart
# Name: 4368, dtype: object
# 0    Gemüsepaprika grün frisch
# Name: 4382, dtype: object
# 0    Gemüsepaprika rot frisch
# Name: 4396, dtype: object
# 0    Gemüsepaprika rot Konserve
# Name: 4410, dtype: object
# 0    Tomaten frisch gegart
# Name: 4424, dtype: object
# 0    Tomaten Konzentrat
# Name: 4438, dtype: object
# 0    Tomaten Gemüsesaft
# Name: 4452, dtype: object
# 0    Tomaten Konserve gegart
# Name: 4466, dtype: object
# 0    Tomate rot frisch
# Name: 4480, dtype: object
# 0    Zuckermais frisch gegart
# Name: 4494, dtype: object
# 0    Zuckermais Konserve, abgetropft
# Name: 4508, dtype: object
# 0    Kürbis frisch gegart
# Name: 4522, dtype: object
# 0    Zucchini frisch
# Name: 4536, dtype: object
# 0    Zucchini frisch gegart
# Name: 4550, dtype: object
# 0    Gartenkürbis frisch
# Name: 4564, dtype: object
# 0    Kohlrübe (Steckrübe) gegart
# Name: 4578, dtype: object
# 0    Rote Rübe frisch
# Name: 4592, dtype: object
# 0    Rote Rübe frisch gegart
# Name: 4606, dtype: object
# 0    Rote Rübe Konserve gegart
# Name: 4620, dtype: object
# 0    Mohrrübe Karotte frisch
# Name: 4634, dtype: object
# 0    Mohrrübe Karotte frisch gegart
# Name: 4648, dtype: object
# 0    Mohrrübe Karotte Gemüsesaft
# Name: 4662, dtype: object
# 0    Mohrrübe Karotte Konserve gegart
# Name: 4676, dtype: object
# 0    Meerrettich Konserve
# Name: 4690, dtype: object
# 0    Pastinake frisch
# Name: 4704, dtype: object
# 0    Pastinake frisch gegart
# Name: 4718, dtype: object
# 0    Schwarzwurzel frisch
# Name: 4732, dtype: object
# 0    Schwarzwurzel frisch gegart
# Name: 4746, dtype: object
# 0    Schwarzwurzel Konserve gegart
# Name: 4760, dtype: object
# 0    Knollensellerie frisch
# Name: 4774, dtype: object
# 0    Knollensellerie frisch gegart
# Name: 4788, dtype: object
# 0    Rettich frisch
# Name: 4802, dtype: object
# 0    Radieschen frisch
# Name: 4816, dtype: object
# 0    Bohnen grün gegart
# Name: 4830, dtype: object
# 0    Bohnen grün tiefgefroren gegart
# Name: 4844, dtype: object
# 0    Bohnen grün Konserve gegart
# Name: 4858, dtype: object
# 0    Wachsbohnen gegart
# Name: 4872, dtype: object
# 0    Wachsbohnen Konserve gegart
# Name: 4886, dtype: object
# 0    Bohnen dick getrocknet
# Name: 4900, dtype: object
# 0    Sojabohnen getrocknet
# Name: 4914, dtype: object
# 0    Erbsen grün frisch
# Name: 4928, dtype: object
# 0    Erbsen grün frisch gegart
# Name: 4942, dtype: object
# 0    Erbsen grün tiefgefroren gegart
# Name: 4956, dtype: object
# 0    Erbsen grün Konserve gegart
# Name: 4970, dtype: object
# 0    Kichererbsen getrocknet
# Name: 4984, dtype: object
# 0    Limabohne getrocknet gegart
# Name: 4998, dtype: object
# 0    Blumenkohlsuppe Trockenprodukt
# Name: 5012, dtype: object
# 0    Wurzel, Knollengemüsesuppen tro.
# Name: 5026, dtype: object
# 0    Pickles süß milchsauer
# Name: 5040, dtype: object
# 0    Gewürzgurken Sauerkonserve
# Name: 5054, dtype: object
# 0    Cornichons Sauerkonserve
# Name: 5068, dtype: object
# 0    Nüsse frisch
# Name: 5082, dtype: object
# 0    Erdnuß geröstet
# Name: 5096, dtype: object
# 0    Walnuß europäisch
# Name: 5110, dtype: object
# 0    Haselnuß frisch
# Name: 5124, dtype: object
# 0    Kokosnuß Raspeln
# Name: 5138, dtype: object
# 0    Kokosmilch
# Name: 5152, dtype: object
# 0    Cashewnuß geröstet
# Name: 5166, dtype: object
# 0    Paranuß frisch
# Name: 5180, dtype: object
# 0    Mandel frisch
# Name: 5194, dtype: object
# 0    Edelkastanien frisch gegart
# Name: 5208, dtype: object
# 0    Edelkastanien geröstet
# Name: 5222, dtype: object
# 0    Pistazie geröstet und gesalzen
# Name: 5236, dtype: object
# 0    Kürbiskern frisch
# Name: 5250, dtype: object
# 0    Pinienkern frisch
# Name: 5264, dtype: object
# 0    Leinsamen frisch
# Name: 5278, dtype: object
# 0    Sesam frisch
# Name: 5292, dtype: object
# 0    Sonnenblumenkern frisch
# Name: 5306, dtype: object
# 0    Mohn frisch
# Name: 5320, dtype: object
# 0    Oliven grün gesäuert
# Name: 5334, dtype: object
# 0    Oliven schwarz gesäuert
# Name: 5348, dtype: object
# 0    Bambussprossen Konserve gegart
# Name: 5362, dtype: object
# 0    Luzernensprossen (Alfalfa)
# Name: 5376, dtype: object
# 0    Mungobohnensprossen
# Name: 5390, dtype: object
# 0    Getreidesprossen (gekeimt)
# Name: 5404, dtype: object
# 0    Hülsenfrüchte reif
# Name: 5418, dtype: object
# 0    Erbsen reif frisch gegart
# Name: 5432, dtype: object
# 0    Linsen reif Konserve gegart
# Name: 5446, dtype: object
# 0    Bohne weiß frisch gegart
# Name: 5460, dtype: object
# 0    Bohnen weiß reif Konserve gegart
# Name: 5474, dtype: object
# 0    Kidney-Bohnen Konserve
# Name: 5488, dtype: object
# 0    Studentenfutter
# Name: 5502, dtype: object
# 0    Hülsenfruchtgerichte Konserve
# Name: 5516, dtype: object
# 0    Sojabohne geröstet
# Name: 5530, dtype: object
# 0    Sojamehl (entfettet) entbittert
# Name: 5544, dtype: object
# 0    Sojaeiweiß texturiert (TVP)
# Name: 5558, dtype: object
# 0    Sojamilch flüssig
# Name: 5572, dtype: object
# 0    Tofu frisch
# Name: 5586, dtype: object
# 0    Vegetarische Bratlinge Trockenprodukt
# Name: 5600, dtype: object
# 0    Sojafleisch mit Gewürzen trocken
# Name: 5614, dtype: object
# 0    Vegetarische Pasteten
# Name: 5628, dtype: object
# 0    Sojaaufschnitt
# Name: 5642, dtype: object
# 0    Hefeextrakt (Hefeaufstrichpaste)
# Name: 5656, dtype: object
# 0    Bratlinge vegetarisch
# Name: 5670, dtype: object
# 0    Sojawurst Konserve
# Name: 5684, dtype: object
# 0    Kartoffeln geschält frisch gegart
# Name: 5698, dtype: object
# 0    Kartoffelbreipulver
# Name: 5712, dtype: object
# 0    Kartoffelstärke Mehl
# Name: 5726, dtype: object
# 0    Kartoffelkloß gekocht Trockenprodukt
# Name: 5740, dtype: object
# 0    Kartoffelchips
# Name: 5754, dtype: object
# 0    Maniok (Cassava)
# Name: 5768, dtype: object
# 0    Batate (Süßkartoffel)
# Name: 5782, dtype: object
# 0    Topinambur frisch
# Name: 5796, dtype: object
# 0    Tapioka
# Name: 5810, dtype: object
# 0    Pilze frisch gegart
# Name: 5824, dtype: object
# 0    Pilze Konserve gegart
# Name: 5838, dtype: object
# 0    Champignon gegart
# Name: 5852, dtype: object
# 0    Champignon frisch
# Name: 5866, dtype: object
# 0    Champignon Konserve gegart
# Name: 5880, dtype: object
# 0    Pfifferling frisch
# Name: 5894, dtype: object
# 0    Pfifferling getrocknet
# Name: 5908, dtype: object
# 0    Pfifferling Konserve
# Name: 5922, dtype: object
# 0    Steinpilz frisch
# Name: 5936, dtype: object
# 0    Steinpilz getrocknet
# Name: 5950, dtype: object
# 0    Steinpilz Konserve
# Name: 5964, dtype: object
# 0    Shiitakepilz frisch
# Name: 5978, dtype: object
# 0    Waldpilze
# Name: 5992, dtype: object
# 0    Champignoncremesuppe Trockenprodukt
# Name: 6006, dtype: object
# 0    Brot eiweißarm glutenfrei
# Name: 6020, dtype: object
# 0    Waffeln eiweißarm glutenfrei
# Name: 6034, dtype: object
# 0    Plätzchen eiweißarm glutenfrei
# Name: 6048, dtype: object
# 0    Mehlmischung für Brot glutenfrei
# Name: 6062, dtype: object
# 0    Zwieback glutenfrei
# Name: 6076, dtype: object
# 0    Waffel-Maisbrot glutenfrei
# Name: 6090, dtype: object
# 0    Hirsebrot glutenfrei
# Name: 6104, dtype: object
# 0    Kastanienbrot glutenfrei
# Name: 6118, dtype: object
# 0    Maiskeks glutenfrei
# Name: 6132, dtype: object
# 0    Energieriegel mit Haselnußcreme
# Name: 6146, dtype: object
# 0    Diabetiker Zucker
# Name: 6160, dtype: object
# 0    Diabetiker Brotaufstriche
# Name: 6174, dtype: object
# 0    Konfitüre mit Fruktose und Süßstoff
# Name: 6188, dtype: object
# 0    Diabetiker Schokolade
# Name: 6202, dtype: object
# 0    Diabetiker Süßigkeiten
# Name: 6216, dtype: object
# 0    Diabetiker Backwaren
# Name: 6230, dtype: object
# 0    Vollkornzwieback für Diabetiker
# Name: 6244, dtype: object
# 0    Diabetiker Gebäck
# Name: 6258, dtype: object
# 0    Saccharin-Cyclamat-Mischung Tabl.
# Name: 6272, dtype: object
# 0    Wurst- und Fleischwaren fettarm
# Name: 6286, dtype: object
# 0    Fruchtjoghurt mit Süßstoff
# Name: 6300, dtype: object
# 0    Fruchtquark mit Süßstoff
# Name: 6314, dtype: object
# 0    Fruchtdickmilch mit Süßstoff
# Name: 6328, dtype: object
# 0    Orangensaft mit Süßstoff
# Name: 6342, dtype: object
# 0    Multi-Vitamin-Nektar mit Süßstoff
# Name: 6356, dtype: object
# 0    Kochsalzersatz mineralstoffreich
# Name: 6370, dtype: object
# 0    Schafskäse
# Name: 6384, dtype: object
# 0    Roquefort
# Name: 6398, dtype: object
# 0    Feta
# Name: 6412, dtype: object
# 0    Mozarella
# Name: 6426, dtype: object
# 0    Kuhmilch gekocht
# Name: 6440, dtype: object
# 0    Kuhmilch entrahmt gekocht
# Name: 6454, dtype: object
# 0    Kuhmilch teilentrahmt gekocht
# Name: 6468, dtype: object
# 0    Kuhmilch Trinkmilch entrahmt
# Name: 6482, dtype: object
# 0    Kuhmilch Trinkmilch fettarm
# Name: 6496, dtype: object
# 0    Kuhmilch Trinkmilch vollfett
# Name: 6510, dtype: object
# 0    Kuhmilch Vorzugsmilch vollfett
# Name: 6524, dtype: object
# 0    Dickmilch (Sauermilch)
# Name: 6538, dtype: object
# 0    Dickmilch (Sauermilch) entrahmt
# Name: 6552, dtype: object
# 0    Dickmilch (Sauermilch) teilentrahmt
# Name: 6566, dtype: object
# 0    Dickmilch (Sauermilch) 10% Fett
# Name: 6580, dtype: object
# 0    Schwedenmilch vollfett
# Name: 6594, dtype: object
# 0    Kefir
# Name: 6608, dtype: object
# 0    Kefir entrahmt
# Name: 6622, dtype: object
# 0    Joghurt entrahmt (0,1 %)
# Name: 6636, dtype: object
# 0    Joghurt teilentrahmt (1,5 %)
# Name: 6650, dtype: object
# 0    Joghurt vollfett (3,5 %)
# Name: 6664, dtype: object
# 0    Buttermilch
# Name: 6678, dtype: object
# 0    Molke
# Name: 6692, dtype: object
# 0    Kaffeesahne
# Name: 6706, dtype: object
# 0    Saure Sahne 10 % Fett
# Name: 6720, dtype: object
# 0    Saure Sahne 20 % Fett
# Name: 6734, dtype: object
# 0    Saure Sahne 30 % Fett
# Name: 6748, dtype: object
# 0    Saure Sahne 40 % Fett
# Name: 6762, dtype: object
# 0    Schlagsahne 30 % Fett
# Name: 6776, dtype: object
# 0    Kondensmilch gezuckert 10 % Fett
# Name: 6790, dtype: object
# 0    Kondensmilch 4% Fett
# Name: 6804, dtype: object
# 0    Kondensmilch 7.5 % Fett
# Name: 6818, dtype: object
# 0    Kondensmilch 10 % Fett
# Name: 6832, dtype: object
# 0    Trinkmilch mit Kakao/Schokolade
# Name: 6846, dtype: object
# 0    Dickmilch fettarm mit Früchten
# Name: 6860, dtype: object
# 0    Dickmilch 10 % mit Früchten
# Name: 6874, dtype: object
# 0    Dickmilch mit Müsli
# Name: 6888, dtype: object
# 0    Joghurt mit Früchten
# Name: 6902, dtype: object
# 0    Joghurt fettarm mit Früchten
# Name: 6916, dtype: object
# 0    Joghurt vollfett mit Früchten
# Name: 6930, dtype: object
# 0    Joghurt 10% mit Früchten
# Name: 6944, dtype: object
# 0    Joghurt mit Müsli
# Name: 6958, dtype: object
# 0    Buttermilch mit Fruchtzubereitung
# Name: 6972, dtype: object
# 0    Hartkäse
# Name: 6986, dtype: object
# 0    Hartkäse Magerstufe
# Name: 7000, dtype: object
# 0    Hartkäse Dreiviertelfettstufe
# Name: 7014, dtype: object
# 0    Hartkäse Vollfettstufe
# Name: 7028, dtype: object
# 0    Hartkäse Rahmstufe
# Name: 7042, dtype: object
# 0    Bergkäse Vollfettstufe
# Name: 7056, dtype: object
# 0    Chester
# Name: 7070, dtype: object
# 0    Emmentaler Vollfettstufe
# Name: 7084, dtype: object
# 0    Greyerzer
# Name: 7098, dtype: object
# 0    Parmesan
# Name: 7112, dtype: object
# 0    Raquelette Rahmstufe
# Name: 7126, dtype: object
# 0    Jarlsberg Vollfettstufe
# Name: 7140, dtype: object
# 0    Cheddar Rahmstufe
# Name: 7154, dtype: object
# 0    Schnittkäse
# Name: 7168, dtype: object
# 0    Schnittkäse Dreiviertelfettstufe
# Name: 7182, dtype: object
# 0    Schnittkäse Fettstufe
# Name: 7196, dtype: object
# 0    Schnittkäse Vollfettstufe
# Name: 7210, dtype: object
# 0    Schnittkäse Rahmstufe
# Name: 7224, dtype: object
# 0    Edamer
# Name: 7238, dtype: object
# 0    Gouda
# Name: 7252, dtype: object
# 0    Tilsiter
# Name: 7266, dtype: object
# 0    Fontina
# Name: 7280, dtype: object
# 0    Schnittkäse halbfest
# Name: 7294, dtype: object
# 0    Schnittkäse halbf. Dreiviertelf.
# Name: 7308, dtype: object
# 0    Schnittkäse halbf. Fettstufe
# Name: 7322, dtype: object
# 0    Schnittkäse halbf. Vollfettstufe
# Name: 7336, dtype: object
# 0    Schnittkäse halbf. Rahmstufe
# Name: 7350, dtype: object
# 0    Schnittkäse halbf. Doppelrahmst.
# Name: 7364, dtype: object
# 0    Butterkäse
# Name: 7378, dtype: object
# 0    Edelpilzkäse
# Name: 7392, dtype: object
# 0    Trappisten Vollfettstufe
# Name: 7406, dtype: object
# 0    Esrom Vollfettstufe
# Name: 7420, dtype: object
# 0    Blauschimmel Rahmstufe
# Name: 7434, dtype: object
# 0    Danablu Rahmstufe
# Name: 7448, dtype: object
# 0    Stilton Doppelrahmstufe
# Name: 7462, dtype: object
# 0    Gorgonzola Magerstufe
# Name: 7476, dtype: object
# 0    Scheiblette
# Name: 7490, dtype: object
# 0    Weichkäse
# Name: 7504, dtype: object
# 0    Weichkäse Halbfettstufe
# Name: 7518, dtype: object
# 0    Weichkäse Dreiviertelfettstufe
# Name: 7532, dtype: object
# 0    Weichkäse Fettstufe
# Name: 7546, dtype: object
# 0    Weichkäse Vollfettstufe
# Name: 7560, dtype: object
# 0    Weichkäse Rahmstufe
# Name: 7574, dtype: object
# 0    Weichkäse Doppelrahmstufe
# Name: 7588, dtype: object
# 0    Weichkäse 70% F.i.Tr.
# Name: 7602, dtype: object
# 0    Brie Rahmstufe
# Name: 7616, dtype: object
# 0    Camembert
# Name: 7630, dtype: object
# 0    Limburger
# Name: 7644, dtype: object
# 0    Romadur Halbfettstufe
# Name: 7658, dtype: object
# 0    Klosterkäse Rahmstufe
# Name: 7672, dtype: object
# 0    Frischkäse
# Name: 7686, dtype: object
# 0    Frischkäse Rahmstufe
# Name: 7700, dtype: object
# 0    Frischkäse Doppelrahmstufe
# Name: 7714, dtype: object
# 0    Hüttenkäse
# Name: 7728, dtype: object
# 0    Hüttenkäse Magerstufe
# Name: 7742, dtype: object
# 0    Quark Magerstufe
# Name: 7756, dtype: object
# 0    Quark Halbfettstufe (20 %)
# Name: 7770, dtype: object
# 0    Quark Fettstufe (40 %)
# Name: 7784, dtype: object
# 0    Sauermilchkäse Magerstufe
# Name: 7798, dtype: object
# 0    Ricotta Doppelrahmstufe
# Name: 7812, dtype: object
# 0    Schmelzkäse
# Name: 7826, dtype: object
# 0    Schmelzkäse Halbfettstufe
# Name: 7840, dtype: object
# 0    Frischkäsezubereitung
# Name: 7854, dtype: object
# 0    Quark mit Früchten
# Name: 7868, dtype: object
# 0    Quark mit Kräutern Fettstufe
# Name: 7882, dtype: object
# 0    Kaffeeweißer
# Name: 7896, dtype: object
# 0    Vollmilchpulver
# Name: 7910, dtype: object
# 0    Magermilchpulver
# Name: 7924, dtype: object
# 0    Buttermilchpulver
# Name: 7938, dtype: object
# 0    Trinkwasser
# Name: 7952, dtype: object
# 0    Mineralwasser mit Kohlensäure
# Name: 7966, dtype: object
# 0    Natürliches Mineralwasser still
# Name: 7980, dtype: object
# 0    Fruchtsaftgetränke
# Name: 7994, dtype: object
# 0    Limonaden
# Name: 8008, dtype: object
# 0    Limonaden kalorienarm
# Name: 8022, dtype: object
# 0    Brausen
# Name: 8036, dtype: object
# 0    Brausen kalorienarm
# Name: 8050, dtype: object
# 0    Colagetränke (coffeinhaltig)
# Name: 8064, dtype: object
# 0    Colagetränke kalorienarm
# Name: 8078, dtype: object
# 0    Getränkepulver
# Name: 8092, dtype: object
# 0    Cola Mix
# Name: 8106, dtype: object
# 0    Bohnenkaffee
# Name: 8120, dtype: object
# 0    Kaffee mit Milch (Getränk)
# Name: 8134, dtype: object
# 0    Kaffee mit Milch,Zucker (Getränk
# Name: 8148, dtype: object
# 0    Kaffee mit Kondensmilch
# Name: 8162, dtype: object
# 0    Kaffee mit Kondensm. und Zucker
# Name: 8176, dtype: object
# 0    Kaffee mit Zucker
# Name: 8190, dtype: object
# 0    Kaffee Instantpulver (trocken)
# Name: 8204, dtype: object
# 0    Kaffee Ersatz
# Name: 8218, dtype: object
# 0    Kaffee Ersatz mit Kondensm.
# Name: 8232, dtype: object
# 0    Kaffee Ersatz m. Kondensm./Zucke
# Name: 8246, dtype: object
# 0    Kaffee Ersatz mit Zucker
# Name: 8260, dtype: object
# 0    Tee
# Name: 8274, dtype: object
# 0    Tee schwarz mit Milch
# Name: 8288, dtype: object
# 0    Tee schwarz mit Milch/Zucker
# Name: 8302, dtype: object
# 0    Tee schwarz mit Zucker
# Name: 8316, dtype: object
# 0    Kräutertee
# Name: 8330, dtype: object
# 0    Kräutertee mit Zucker
# Name: 8344, dtype: object
# 0    Bier
# Name: 8358, dtype: object
# 0    Bier alkoholfrei
# Name: 8372, dtype: object
# 0    Bier alkoholarm
# Name: 8386, dtype: object
# 0    Malzbier
# Name: 8400, dtype: object
# 0    Weizenbier (Weißbier) obergärig
# Name: 8414, dtype: object
# 0    Weizenbier Export
# Name: 8428, dtype: object
# 0    Bier Pils Hell
# Name: 8442, dtype: object
# 0    Bier Starkbier
# Name: 8456, dtype: object
# 0    Bier mit Limonade
# Name: 8470, dtype: object
# 0    Weißwein/Rotwein
# Name: 8484, dtype: object
# 0    Weißwein trocken
# Name: 8498, dtype: object
# 0    Weißwein Auslese
# Name: 8512, dtype: object
# 0    Weißwein halbtrocken
# Name: 8526, dtype: object
# 0    Rotwein mittel Qualitätswein
# Name: 8540, dtype: object
# 0    Rotwein schwer
# Name: 8554, dtype: object
# 0    Glühwein
# Name: 8568, dtype: object
# 0    Schorle
# Name: 8582, dtype: object
# 0    Bowle Punsch
# Name: 8596, dtype: object
# 0    Sekt
# Name: 8610, dtype: object
# 0    Apfelwein
# Name: 8624, dtype: object
# 0    Likörwein süß und trocken
# Name: 8638, dtype: object
# 0    Liköre
# Name: 8652, dtype: object
# 0    Eierlikör
# Name: 8666, dtype: object
# 0    Kräuter-/ Gewürz-/ Bitterlikör
# Name: 8680, dtype: object
# 0    Weinbrand
# Name: 8694, dtype: object
# 0    Klarer/Schnaps 32 %
# Name: 8708, dtype: object
# 0    Branntwein aus Getreide
# Name: 8722, dtype: object
# 0    Rum >38%
# Name: 8736, dtype: object
# 0    Cocktails
# Name: 8750, dtype: object
# 0    Olivenöl
# Name: 8764, dtype: object
# 0    Pflanzliche Öle
# Name: 8778, dtype: object
# 0    Erdnußöl
# Name: 8792, dtype: object
# 0    Weizenkeimöl
# Name: 8806, dtype: object
# 0    Sesamöl
# Name: 8820, dtype: object
# 0    Maiskeimöl
# Name: 8834, dtype: object
# 0    Sojaöl
# Name: 8848, dtype: object
# 0    Walnußöl
# Name: 8862, dtype: object
# 0    Sonnenblumenöl
# Name: 8876, dtype: object
# 0    Traubenkernöl
# Name: 8890, dtype: object
# 0    Distelöl (Safloröl)
# Name: 8904, dtype: object
# 0    Margarine pflanzlich
# Name: 8918, dtype: object
# 0    Margarine Linolsäure >50%
# Name: 8932, dtype: object
# 0    Margarine halbfett
# Name: 8946, dtype: object
# 0    Margarine zum Kochen
# Name: 8960, dtype: object
# 0    Erdnußbutter/-mus
# Name: 8974, dtype: object
# 0    Kokosfett gehärtet
# Name: 8988, dtype: object
# 0    Palmkernfett
# Name: 9002, dtype: object
# 0    Butter
# Name: 9016, dtype: object
# 0    Butter halbfett
# Name: 9030, dtype: object
# 0    Butterschmalz
# Name: 9044, dtype: object
# 0    Lebertran
# Name: 9058, dtype: object
# 0    Schweineschmalz/-fett
# Name: 9072, dtype: object
# 0    Rindertalg
# Name: 9086, dtype: object
# 0    Bratfett
# Name: 9100, dtype: object
# 0    Fritierfett
# Name: 9114, dtype: object
# 0    Mayonnaise 80% Fett
# Name: 9128, dtype: object
# 0    Salatmayonnaise 50% Fett
# Name: 9142, dtype: object
# 0    Speisesalz
# Name: 9156, dtype: object
# 0    Kräutersalz
# Name: 9170, dtype: object
# 0    Essig
# Name: 9184, dtype: object
# 0    Senf
# Name: 9198, dtype: object
# 0    Würzsoßen und andere Würzmittel
# Name: 9212, dtype: object
# 0    Tomatenketchup
# Name: 9226, dtype: object
# 0    Sojasoße Fertigprodukt
# Name: 9240, dtype: object
# 0    Barbecue-Grillsoße
# Name: 9254, dtype: object
# 0    Schaschlik-Grillsoße
# Name: 9268, dtype: object
# 0    Maggi
# Name: 9282, dtype: object
# 0    Tomatenmark
# Name: 9296, dtype: object
# 0    Orangeat
# Name: 9310, dtype: object
# 0    Zitronat (Sukkade)
# Name: 9324, dtype: object
# 0    Backpulver
# Name: 9338, dtype: object
# 0    Hefe
# Name: 9352, dtype: object
# 0    Tortengußpulver
# Name: 9366, dtype: object
# 0    Gelatine
# Name: 9380, dtype: object
# 0    Stärke
# Name: 9394, dtype: object
# 0    Pudding-/Soßenpulver
# Name: 9408, dtype: object
# 0    Brühwürfel
# Name: 9422, dtype: object
# 0    Brühwürfel fettreich
# Name: 9436, dtype: object
# 0    Bratensoße (Trockenpulver)
# Name: 9450, dtype: object
# 0    Süßwaren
# Name: 9464, dtype: object
# 0    Zucker
# Name: 9478, dtype: object
# 0    Zucker braun Rohrzucker
# Name: 9492, dtype: object
# 0    Traubenzucker
# Name: 9506, dtype: object
# 0    Milchzucker
# Name: 9520, dtype: object
# 0    Fruchtzucker
# Name: 9534, dtype: object
# 0    Blütenhonig-Mischungen
# Name: 9548, dtype: object
# 0    Kunsthonig
# Name: 9562, dtype: object
# 0    Konfitüre Gelee Marmeladen
# Name: 9576, dtype: object
# 0    Konfitüre einfach
# Name: 9590, dtype: object
# 0    Gelee einfach
# Name: 9604, dtype: object
# 0    Marmelade
# Name: 9618, dtype: object
# 0    Nuß-Nougat-Creme süß
# Name: 9632, dtype: object
# 0    Sirup
# Name: 9646, dtype: object
# 0    Pflaumenmus
# Name: 9660, dtype: object
# 0    Sorbet
# Name: 9674, dtype: object
# 0    Cremeeis
# Name: 9688, dtype: object
# 0    Fruchteis
# Name: 9702, dtype: object
# 0    Rahmeis
# Name: 9716, dtype: object
# 0    Milchspeiseeis
# Name: 9730, dtype: object
# 0    Kunstspeiseeis
# Name: 9744, dtype: object
# 0    Softeis
# Name: 9758, dtype: object
# 0    Zuckerwaren
# Name: 9772, dtype: object
# 0    Weichkaramellen Bonbons
# Name: 9786, dtype: object
# 0    Toffees
# Name: 9800, dtype: object
# 0    Gummibonbons
# Name: 9814, dtype: object
# 0    Kaugummi
# Name: 9828, dtype: object
# 0    Lakritze
# Name: 9842, dtype: object
# 0    Marzipan
# Name: 9856, dtype: object
# 0    Geleefrüchte
# Name: 9870, dtype: object
# 0    Nougat
# Name: 9884, dtype: object
# 0    Dragees
# Name: 9898, dtype: object
# 0    Nuß dragiert
# Name: 9912, dtype: object
# 0    Erdnuß dragiert
# Name: 9926, dtype: object
# 0    Kirsche kandiert
# Name: 9940, dtype: object
# 0    Cocktail-Kirsche
# Name: 9954, dtype: object
# 0    Fruchtmischung-Kanditen
# Name: 9968, dtype: object
# 0    Krokant
# Name: 9982, dtype: object
# 0    Schokolade
# Name: 9996, dtype: object
# 0    Milchschokolade
# Name: 10010, dtype: object
# 0    Milchschokolade Vollmilch-Nuß
# Name: 10024, dtype: object
# 0    Zartbitterschokolade
# Name: 10038, dtype: object
# 0    Schokolade weiß
# Name: 10052, dtype: object
# 0    Pralinen gefüllt mit Sonstigem
# Name: 10066, dtype: object
# 0    Pralinen gefüllt mit Alkohol
# Name: 10080, dtype: object
# 0    Pralinen gefüllt mit Nüssen
# Name: 10094, dtype: object
# 0    Schokolade gefüllt mit Sonstigem
# Name: 10108, dtype: object
# 0    Schokoladenüberzugsmassen
# Name: 10122, dtype: object
# 0    Kakaopulver
# Name: 10136, dtype: object
# 0    Kakaopulver-Getränk löslich
# Name: 10150, dtype: object
# 0    Müsli-Riegel
# Name: 10164, dtype: object
# 0    Fische gegart
# Name: 10178, dtype: object
# 0    Tintenfisch tiefgefroren gegart
# Name: 10192, dtype: object
# 0    Dornhai(Seeaal)/Schillerlocke
# Name: 10206, dtype: object
# 0    Aal frisch Zuschnitt gegart
# Name: 10220, dtype: object
# 0    Aal geräuchert
# Name: 10234, dtype: object
# 0    Hecht frisch gegart Zuschnitt
# Name: 10248, dtype: object
# 0    Seeteufel frisch
# Name: 10262, dtype: object
# 0    Heringsf. Makrelen Thunf. gegart
# Name: 10276, dtype: object
# 0    Hering Konserve in Öl
# Name: 10290, dtype: object
# 0    Matjeshering gesalzen
# Name: 10304, dtype: object
# 0    Sardelle gesalzen
# Name: 10318, dtype: object
# 0    Sardine gegart
# Name: 10332, dtype: object
# 0    Sardine geräuchert
# Name: 10346, dtype: object
# 0    Sardine Konserve in Öl
# Name: 10360, dtype: object
# 0    Sprotte frisch
# Name: 10374, dtype: object
# 0    Sprotte geräuchert
# Name: 10388, dtype: object
# 0    Makrele frisch gegart Zuschnitt
# Name: 10402, dtype: object
# 0    Makrele Konserve in Öl
# Name: 10416, dtype: object
# 0    Thunfisch gebraten Zuschnitt
# Name: 10430, dtype: object
# 0    Thunfisch Konserve in Öl
# Name: 10444, dtype: object
# 0    Dorschartige Fische gegart
# Name: 10458, dtype: object
# 0    Kabeljau tiefgefroren gegart
# Name: 10472, dtype: object
# 0    Schellfisch frisch gegart Zuschnitt
# Name: 10486, dtype: object
# 0    Steinbutt frisch gegart Zuschnitt
# Name: 10500, dtype: object
# 0    Scholle frisch gegart Zuschnitt
# Name: 10514, dtype: object
# 0    Heilbutt frisch gegart Zuschnitt
# Name: 10528, dtype: object
# 0    Schwarzer Heilbutt geräuchert
# Name: 10542, dtype: object
# 0    Seezunge frisch gegart Zuschnitt
# Name: 10556, dtype: object
# 0    Flunder frisch gegart Zuschnitt
# Name: 10570, dtype: object
# 0    Lachsfische gegart
# Name: 10584, dtype: object
# 0    Renke frisch gegart Zuschnitt
# Name: 10598, dtype: object
# 0    Lachs frisch
# Name: 10612, dtype: object
# 0    Lachs geräuchert
# Name: 10626, dtype: object
# 0    Forelle frisch gegart Zuschnitt
# Name: 10640, dtype: object
# 0    Forelle geräuchert
# Name: 10654, dtype: object
# 0    Karpfen frisch gegart Zuschnitt
# Name: 10668, dtype: object
# 0    Wels frisch gegart Zuschnitt
# Name: 10682, dtype: object
# 0    Schleie frisch gegart Zuschnitt
# Name: 10696, dtype: object
# 0    Barsch frisch gegart Zuschnitt
# Name: 10710, dtype: object
# 0    Zander frisch gegart Zuschnitt
# Name: 10724, dtype: object
# 0    Rotbarsch gegart Zuschnitt
# Name: 10738, dtype: object
# 0    Krebstiere (Krustentiere) gegart
# Name: 10752, dtype: object
# 0    Flußkrebs (Edelkrebs) gegart
# Name: 10766, dtype: object
# 0    Languste Konserve, abgetropft
# Name: 10780, dtype: object
# 0    Hummer frisch gegart
# Name: 10794, dtype: object
# 0    Krabbe klein (Shrimps) gegart
# Name: 10808, dtype: object
# 0    Garnele frisch
# Name: 10822, dtype: object
# 0    Auster frisch gegart
# Name: 10836, dtype: object
# 0    Miesmuschel frisch gegart
# Name: 10850, dtype: object
# 0    Miesmuschel Konserve in Öl
# Name: 10864, dtype: object
# 0    Jakobsmuschel
# Name: 10878, dtype: object
# 0    Stockfisch tiefgefroren
# Name: 10892, dtype: object
# 0    Bückling
# Name: 10906, dtype: object
# 0    Bismarckhering Konserve, abgetr.
# Name: 10920, dtype: object
# 0    Heringsfilet in Sahne-Meerrettich-Soße
# Name: 10934, dtype: object
# 0    Heringsfilet in Tomatensoße
# Name: 10948, dtype: object
# 0    Brathering Konserve, abgetropft
# Name: 10962, dtype: object
# 0    Kaviar echt
# Name: 10976, dtype: object
# 0    Kaviarersatz
# Name: 10990, dtype: object
# 0    Fischstäbchen paniert tiefgefr.
# Name: 11004, dtype: object
# 0    Fleisch gegart
# Name: 11018, dtype: object
# 0    Fleisch frisch
# Name: 11032, dtype: object
# 0    Rind Hackfleisch gegart
# Name: 11046, dtype: object
# 0    Schwein Hackfleisch gegart
# Name: 11060, dtype: object
# 0    Rind/Schwein Hackfleisch gegart
# Name: 11074, dtype: object
# 0    Brät frisch
# Name: 11088, dtype: object
# 0    Tatar frisch
# Name: 11102, dtype: object
# 0    Rind Fleisch (mager) frisch gegart
# Name: 11116, dtype: object
# 0    Rind Fleisch (mittelfett) frisch gegart
# Name: 11130, dtype: object
# 0    Rind Fleisch (fett) frisch gegart
# Name: 11144, dtype: object
# 0    Rind Filet (Lende) (mager) gegart
# Name: 11158, dtype: object
# 0    Kalb Fleisch gegart
# Name: 11172, dtype: object
# 0    Kalb Fleisch (mager) frisch gegart
# Name: 11186, dtype: object
# 0    Kalb Fleisch (mittelfett) frisch gegart
# Name: 11200, dtype: object
# 0    Kalb (Kotelett) (mf) gegart
# Name: 11214, dtype: object
# 0    Kalb Vorderhaxe (mittelfett) gegart
# Name: 11228, dtype: object
# 0    Schwein Fleisch gegart
# Name: 11242, dtype: object
# 0    Schwein Fleisch gepök. geräuchert
# Name: 11256, dtype: object
# 0    Schwein Fleisch gepök. ungeräuch.
# Name: 11270, dtype: object
# 0    Schwein Fleisch mager
# Name: 11284, dtype: object
# 0    Schwein Fleisch mittelfett
# Name: 11298, dtype: object
# 0    Schwein Fleisch fett
# Name: 11312, dtype: object
# 0    Schwein Kotelett (mittelfett) gegart
# Name: 11326, dtype: object
# 0    Schwein Schnitzel
# Name: 11340, dtype: object
# 0    Schwein Eisbein vorn (mitteflett) gegart
# Name: 11354, dtype: object
# 0    Schaf Fleisch (mager) gegart
# Name: 11368, dtype: object
# 0    Schaf Fleisch (fett) gegart
# Name: 11382, dtype: object
# 0    Schaf Bratenfleisch (mittelfett) gegart
# Name: 11396, dtype: object
# 0    Corned Beef deutsch Konserve
# Name: 11410, dtype: object
# 0    Ragout Fin Konserve
# Name: 11424, dtype: object
# 0    Ochsenschwanzsuppe klar trocken
# Name: 11438, dtype: object
# 0    Gulaschsuppe Konserve
# Name: 11452, dtype: object
# 0    Bratensoße dunkel Konserve
# Name: 11466, dtype: object
# 0    Bratensoße mit Pilzen Konserve
# Name: 11480, dtype: object
# 0    Pferd Fleisch gegart
# Name: 11494, dtype: object
# 0    Ziege Fleisch (mittelfett) frisch gegart
# Name: 11508, dtype: object
# 0    Hauskaninchen Fleisch gegart
# Name: 11522, dtype: object
# 0    Ferkel Fleisch (mittelfett) frisch
# Name: 11536, dtype: object
# 0    Hirsch Fleisch (mittelfett) frisch gegart
# Name: 11550, dtype: object
# 0    Reh Fleisch (mittelfett) frisch gegart
# Name: 11564, dtype: object
# 0    Hase Fleisch (mager) frisch gegart
# Name: 11578, dtype: object
# 0    Wachtel Fleisch mit Haut frisch
# Name: 11592, dtype: object
# 0    Baby-Pute frisch
# Name: 11606, dtype: object
# 0    Brathähnchen Schenkel gegart
# Name: 11620, dtype: object
# 0    Brathähnchen Brust frisch
# Name: 11634, dtype: object
# 0    Suppenhuhn Fleisch mit Haut
# Name: 11648, dtype: object
# 0    Suppenhuhn Schenkel frisch gegart
# Name: 11662, dtype: object
# 0    Ente Fleisch (mittelfett) frisch
# Name: 11676, dtype: object
# 0    Gans mit Haut frisch gegart
# Name: 11690, dtype: object
# 0    Gans Schenkel frisch gegart
# Name: 11704, dtype: object
# 0    Pute Fleisch mit Haut
# Name: 11718, dtype: object
# 0    Pute Schenkel frisch gegart
# Name: 11732, dtype: object
# 0    Pute Brust frisch
# Name: 11746, dtype: object
# 0    Taube Fleisch Haut frisch gegart
# Name: 11760, dtype: object
# 0    Rind Herz gegart
# Name: 11774, dtype: object
# 0    Schwein Herz gegart
# Name: 11788, dtype: object
# 0    Rind Leber gegart
# Name: 11802, dtype: object
# 0    Kalb Leber gegart
# Name: 11816, dtype: object
# 0    Schwein Leber gegart
# Name: 11830, dtype: object
# 0    Schwein Lunge gegart
# Name: 11844, dtype: object
# 0    Rind Magen/Kutteln gegart
# Name: 11858, dtype: object
# 0    Schwein Magen gegart
# Name: 11872, dtype: object
# 0    Rind Niere gegart
# Name: 11886, dtype: object
# 0    Kalb Niere gegart
# Name: 11900, dtype: object
# 0    Schwein Niere gegart
# Name: 11914, dtype: object
# 0    Kalb Bries gegart
# Name: 11928, dtype: object
# 0    Rind Zunge gegart
# Name: 11942, dtype: object
# 0    Kalb Zunge gegart
# Name: 11956, dtype: object
# 0    Schwein Zunge gegart
# Name: 11970, dtype: object
# 0    Brathähnchen Leber gegart
# Name: 11984, dtype: object
# 0    Mettwurst streichfähig
# Name: 11998, dtype: object
# 0    Teewurst
# Name: 12012, dtype: object
# 0    Cervelatwurst
# Name: 12026, dtype: object
# 0    Salami
# Name: 12040, dtype: object
# 0    Bauernbratwurst
# Name: 12054, dtype: object
# 0    Landjäger
# Name: 12068, dtype: object
# 0    Cabanossi
# Name: 12082, dtype: object
# 0    Wiener Würstchen
# Name: 12096, dtype: object
# 0    Bockwurst
# Name: 12110, dtype: object
# 0    Knackwurst/Dicke/Rote/Servela
# Name: 12124, dtype: object
# 0    Frankfurter Rindswurst
# Name: 12138, dtype: object
# 0    Curry-Bratwurst
# Name: 12152, dtype: object
# 0    Rostbratwurst
# Name: 12166, dtype: object
# 0    Weißwurst Münchener
# Name: 12180, dtype: object
# 0    Schinkenwurst
# Name: 12194, dtype: object
# 0    Fleischkäse
# Name: 12208, dtype: object
# 0    Fleischwurst einfach/Stadtwurst
# Name: 12222, dtype: object
# 0    Gelbwurst
# Name: 12236, dtype: object
# 0    Krakauer
# Name: 12250, dtype: object
# 0    Jagdwurst
# Name: 12264, dtype: object
# 0    Schinkenwurst grob/Lyoner grob
# Name: 12278, dtype: object
# 0    Bierwurst
# Name: 12292, dtype: object
# 0    Leberkäse
# Name: 12306, dtype: object
# 0    Weißer Preßkopf
# Name: 12320, dtype: object
# 0    Gefüllte Kalbsbrust
# Name: 12334, dtype: object
# 0    Geflügelmortadella
# Name: 12348, dtype: object
# 0    Leberwurst fein
# Name: 12362, dtype: object
# 0    Kalbsleberwurst
# Name: 12376, dtype: object
# 0    Leberwurst einfach
# Name: 12390, dtype: object
# 0    Hausmacher Blutwurst
# Name: 12404, dtype: object
# 0    Zungenwurst/Filetwurst
# Name: 12418, dtype: object
# 0    Schwartenmagen
# Name: 12432, dtype: object
# 0    Sülzen und Aspik
# Name: 12446, dtype: object
# 0    Leberpastete
# Name: 12460, dtype: object
# 0    Schwein Speck durchwachsen
# Name: 12474, dtype: object
# 0    Schwein Schinken roh geräuchert
# Name: 12488, dtype: object
# 0    Schwein Schinken gekocht ungeräuchert
# Name: 12502, dtype: object
# 0    Kassler
# Name: 12516, dtype: object
# 0    Schälrippchen
# Name: 12530, dtype: object
# 0    Mortadella Konserve
# Name: 12544, dtype: object
# 0    Wiener Würstchen Konserve
# Name: 12558, dtype: object
# 0    Müsli mit Milch, Zucker und Obst
# Name: 12572, dtype: object
# 0    Möhrensalat gegart mit Öl
# Name: 12586, dtype: object
# 0    Bohnensalat grün gegart mit Öl
# Name: 12600, dtype: object
# 0    Gemüsesalat gegart mit Dressing
# Name: 12614, dtype: object
# 0    Rohkostsalat mit Öl
# Name: 12628, dtype: object
# 0    Rohkostsalat mit Joghurt
# Name: 12642, dtype: object
# 0    Kopfsalat mit Dressing
# Name: 12656, dtype: object
# 0    Salat mit Öl
# Name: 12670, dtype: object
# 0    Kopfsalat mit Joghurt
# Name: 12684, dtype: object
# 0    Krautsalat
# Name: 12698, dtype: object
# 0    Obstsalate
# Name: 12712, dtype: object
# 0    Kartoffelsalat mit Öl gegart
# Name: 12726, dtype: object
# 0    Käsesalat
# Name: 12740, dtype: object
# 0    Nudelsalat mit Mayonnaise
# Name: 12754, dtype: object
# 0    Reissalat mit Gurken und Dressing
# Name: 12768, dtype: object
# 0    Eiersalat
# Name: 12782, dtype: object
# 0    Wurst-Käsesalat
# Name: 12796, dtype: object
# 0    Geflügelsalate
# Name: 12810, dtype: object
# 0    Grundsoße (hell/dunkel)
# Name: 12824, dtype: object
# 0    Grundsoße Senf einfach
# Name: 12838, dtype: object
# 0    Grundsoße weiß
# Name: 12852, dtype: object
# 0    Soße holländisch
# Name: 12866, dtype: object
# 0    Bechamelsoße
# Name: 12880, dtype: object
# 0    Essigmarinade (Essig/Öl)
# Name: 12894, dtype: object
# 0    Vanillesoße süß
# Name: 12908, dtype: object
# 0    Schokoladensoße
# Name: 12922, dtype: object
# 0    Bouillon (Einfache Fleischbrühe)
# Name: 12936, dtype: object
# 0    Fleischbrühe klar
# Name: 12950, dtype: object
# 0    Geflügelbrühe
# Name: 12964, dtype: object
# 0    Gemüsebrühe
# Name: 12978, dtype: object
# 0    Suppen klar mit Einlage
# Name: 12992, dtype: object
# 0    Nudelsuppe
# Name: 13006, dtype: object
# 0    Gemüsesuppe mit Dörrfleisch
# Name: 13020, dtype: object
# 0    Leberspätzle
# Name: 13034, dtype: object
# 0    Suppen gebunden
# Name: 13048, dtype: object
# 0    Tomatencremesuppe
# Name: 13062, dtype: object
# 0    Spargelcremesuppe kochfertig
# Name: 13076, dtype: object
# 0    Kartoffelsuppe
# Name: 13090, dtype: object
# 0    Suppen mit Einlage gebunden
# Name: 13104, dtype: object
# 0    Minestrone (Gemüseeintopf)
# Name: 13118, dtype: object
# 0    Mischgemüse
# Name: 13132, dtype: object
# 0    Gemüseplatte
# Name: 13146, dtype: object
# 0    Erbsen- und Möhrengemüse
# Name: 13160, dtype: object
# 0    Ratatouille (Auberginen, Tomaten, Zucchini)
# Name: 13174, dtype: object
# 0    Lauchgemüse
# Name: 13188, dtype: object
# 0    Paprikaschoten gefüllt
# Name: 13202, dtype: object
# 0    Linsengemüse
# Name: 13216, dtype: object
# 0    Erbseneintopf
# Name: 13230, dtype: object
# 0    Linsen-Eintopf mit Wurst
# Name: 13244, dtype: object
# 0    Bohneneintopf
# Name: 13258, dtype: object
# 0    Irish Stew
# Name: 13272, dtype: object
# 0    Salzkartoffeln
# Name: 13286, dtype: object
# 0    Pellkartoffeln
# Name: 13300, dtype: object
# 0    Kartoffelbrei
# Name: 13314, dtype: object
# 0    Bratkartoffeln
# Name: 13328, dtype: object
# 0    Bratkartoffeln mit Speck + Zwiebeln
# Name: 13342, dtype: object
# 0    Kartoffelkroketten
# Name: 13356, dtype: object
# 0    Pommes Frites
# Name: 13370, dtype: object
# 0    Kartoffelpuffer
# Name: 13384, dtype: object
# 0    Rösti
# Name: 13398, dtype: object
# 0    Kartoffelklöße
# Name: 13412, dtype: object
# 0    Kartoffeleintopf mit Fleisch
# Name: 13426, dtype: object
# 0    Käsespätzle
# Name: 13440, dtype: object
# 0    Lasagne al forno
# Name: 13454, dtype: object
# 0    Gemüse-Lasagne
# Name: 13468, dtype: object
# 0    Schupfnudeln
# Name: 13482, dtype: object
# 0    Spaghetti Bolognese
# Name: 13496, dtype: object
# 0    Makkaroni mit Tomatensoße
# Name: 13510, dtype: object
# 0    Maultaschen schwäbisch
# Name: 13524, dtype: object
# 0    Cannelloni
# Name: 13538, dtype: object
# 0    Ravioli mit Tomatensoße
# Name: 13552, dtype: object
# 0    Nudelgericht mit Gemüse
# Name: 13566, dtype: object
# 0    Milchreis mit Zucker und Zimt
# Name: 13580, dtype: object
# 0    Krapfen Beignets
# Name: 13594, dtype: object
# 0    Gemüserisotto
# Name: 13608, dtype: object
# 0    Paella
# Name: 13622, dtype: object
# 0    Nasi Goreng
# Name: 13636, dtype: object
# 0    Pizza mit Tomaten, Käse und Salami
# Name: 13650, dtype: object
# 0    Frühlingsrolle
# Name: 13664, dtype: object
# 0    Pfannkuchen
# Name: 13678, dtype: object
# 0    Grießbrei
# Name: 13692, dtype: object
# 0    Semmelknödel
# Name: 13706, dtype: object
# 0    Bratwurst
# Name: 13720, dtype: object
# 0    Fleischkäse gebraten
# Name: 13734, dtype: object
# 0    Frikadelle
# Name: 13748, dtype: object
# 0    Hackbraten
# Name: 13762, dtype: object
# 0    Königsberger Klopse
# Name: 13776, dtype: object
# 0    Schaschlik/Spieß Gericht
# Name: 13790, dtype: object
# 0    Leberknödel
# Name: 13804, dtype: object
# 0    Rumpsteak
# Name: 13818, dtype: object
# 0    Rindergulasch mit Soße
# Name: 13832, dtype: object
# 0    Rinderroulade mit Soße
# Name: 13846, dtype: object
# 0    Serbisches Reisfleisch
# Name: 13860, dtype: object
# 0    Schweinekotelett paniert
# Name: 13874, dtype: object
# 0    Schweineschnitzel paniert
# Name: 13888, dtype: object
# 0    Schweineschnitzel natur
# Name: 13902, dtype: object
# 0    Lammkotelett
# Name: 13916, dtype: object
# 0    Hühnerfrikassee
# Name: 13930, dtype: object
# 0    Putenschnitzel
# Name: 13944, dtype: object
# 0    Fisch in Kräutersoße
# Name: 13958, dtype: object
# 0    Fischfrikadelle
# Name: 13972, dtype: object
# 0    Fischfrikassee
# Name: 13986, dtype: object
# 0    Fischfilet paniert
# Name: 14000, dtype: object
# 0    Fischfilet gebraten
# Name: 14014, dtype: object
# 0    Fischfilet gedünstet
# Name: 14028, dtype: object
# 0    Fischstäbchen fritiert
# Name: 14042, dtype: object
# 0    Spiegelei
# Name: 14056, dtype: object
# 0    Rühreigerichte
# Name: 14070, dtype: object
# 0    Rührei mit Speck/Schinken
# Name: 14084, dtype: object
# 0    Omelett
# Name: 14098, dtype: object
# 0    Eierpfannkuchen
# Name: 14112, dtype: object
# 0    Eier gekocht mit Senfsoße
# Name: 14126, dtype: object
# 0    Quarkspeisen roh
# Name: 14140, dtype: object
# 0    Zaziki
# Name: 14154, dtype: object
# 0    Toast Hawai
# Name: 14168, dtype: object
# 0    Käse-Toast mit Schinken
# Name: 14182, dtype: object
# 0    Dampfnudeln
# Name: 14196, dtype: object
# 0    Kompott gemischt
# Name: 14210, dtype: object
# 0    Apfelmus
# Name: 14224, dtype: object
# 0    Rote Grütze
# Name: 14238, dtype: object
# 0    Vanillepudding
# Name: 14252, dtype: object
# 0    Pudding o.A.
# Name: 14266, dtype: object
# 0    Weincreme
# Name: 14280, dtype: object
# 0    Mokkacreme
# Name: 14294, dtype: object
# 0    Quarkauflauf mit Fruchtsoße
# Name: 14308, dtype: object
# 0    Hamburger
# Name: 14322, dtype: object
# 0    Cheeseburger
# Name: 14336, dtype: object
# 0    Big Mac
# Name: 14350, dtype: object
# 0    Eis mit Sahne
# Name: 14364, dtype: object
# 0    Sahne-Frucht-Eis
# Name: 14378, dtype: object
# 0    Eis mit Früchten Sahne u. Alkoho
# Name: 14392, dtype: object
# 0    Eis mit Früchten
# Name: 14406, dtype: object
# 0    Vanilleeis
# Name: 14420, dtype: object
# 0    Blattsalat mit Öl
# Name: 14434, dtype: object
# 0    Blattsalate mit Joghurt
# Name: 14448, dtype: object
# 0    Bratensoße flüssig
# Name: 14462, dtype: object
# 0    Bratkartoffeln
# Name: 14476, dtype: object
# 0    Bratwurst
# Name: 14490, dtype: object
# 0    Brötchen belegt
# Name: 14504, dtype: object
# 0    Eier in Senfsauce
# Name: 14518, dtype: object
# 0    Eierpfannkuchen
# Name: 14532, dtype: object
# 0    Eiersalat
# Name: 14546, dtype: object
# 0    Eintopf
# Name: 14560, dtype: object
# 0    Eis, Sorbet
# Name: 14574, dtype: object
# 0    Erbsen und Möhrengemüse
# Name: 14588, dtype: object
# 0    Fischkonserve
# Name: 14602, dtype: object
# 0    Fischstäbchen
# Name: 14616, dtype: object
# 0    Flammerie, Pudding
# Name: 14630, dtype: object
# 0    Gebundene Suppe
# Name: 14644, dtype: object
# 0    Gemüseplatte
# Name: 14658, dtype: object
# 0    Gemüserisotto
# Name: 14672, dtype: object
# 0    Gemüsesalat mit Dressing
# Name: 14686, dtype: object
# 0    Gemüsesuppe
# Name: 14700, dtype: object
# 0    Gemüsesuppe mit Wurst
# Name: 14714, dtype: object
# 0    Grießbrei
# Name: 14728, dtype: object
# 0    Grundsoße weiß
# Name: 14742, dtype: object
# 0    Gurkensalat
# Name: 14756, dtype: object
# 0    Götterspeise
# Name: 14770, dtype: object
# 0    Hackbraten
# Name: 14784, dtype: object
# 0    Hamburger
# Name: 14798, dtype: object
# 0    Kartoffelbrei
# Name: 14812, dtype: object
# 0    Kartoffelklöße
# Name: 14826, dtype: object
# 0    Kartoffelkroketten
# Name: 14840, dtype: object
# 0    Kartoffelpuffer
# Name: 14854, dtype: object
# 0    Kartoffelsalat
# Name: 14868, dtype: object
# 0    Kebab, Gyros
# Name: 14882, dtype: object
# 0    Klare Suppe mit Einlage
# Name: 14896, dtype: object
# 0    Krautsalat
# Name: 14910, dtype: object
# 0    Käsefondue
# Name: 14924, dtype: object
# 0    Käseplatte
# Name: 14938, dtype: object
# 0    Käsesalat
# Name: 14952, dtype: object
# 0    Mayonnaise
# Name: 14966, dtype: object
# 0    Milchreis
# Name: 14980, dtype: object
# 0    Mohrrübensalat
# Name: 14994, dtype: object
# 0    Müsli mit Milch/Zucker/Obst
# Name: 15008, dtype: object
# 0    Nudelgerichte mit Fleisch
# Name: 15022, dtype: object
# 0    Nudelgerichte mit Gemüse
# Name: 15036, dtype: object
# 0    Nudeln, Spätzle
# Name: 15050, dtype: object
# 0    Obst, Kompott
# Name: 15064, dtype: object
# 0    Obstmischung
# Name: 15078, dtype: object
# 0    Omelett
# Name: 15092, dtype: object
# 0    Pellkartoffeln
# Name: 15106, dtype: object
# 0    Pfannkuchen süß
# Name: 15120, dtype: object
# 0    Pizza
# Name: 15134, dtype: object
# 0    Pommes Frites
# Name: 15148, dtype: object
# 0    Quarkspeisen, Joghurt
# Name: 15162, dtype: object
# 0    Reissalat
# Name: 15176, dtype: object
# 0    Rohkostsalat mit Joghurt
# Name: 15190, dtype: object
# 0    Rohkostsalat mit Öl
# Name: 15204, dtype: object
# 0    Rührei mit Speck/Schinken
# Name: 15218, dtype: object
# 0    Rühreier
# Name: 15232, dtype: object
# 0    Salate
# Name: 15246, dtype: object
# 0    Salzkartoffeln
# Name: 15260, dtype: object
# 0    Semmelknödel
# Name: 15274, dtype: object
# 0    Spiegeleier
# Name: 15288, dtype: object
# 0    Tomatensalat
# Name: 15302, dtype: object
# 0    Tomatensoße
# Name: 15316, dtype: object
# 0    Wiener Schnitzel
# Name: 15330, dtype: object
# 0    Wurst gemischt
# Name: 15344, dtype: object
# 0    Gemüsemischung roh
# Name: 15358, dtype: object
# 0    Fisch paniert
# Name: 15372, dtype: object

# %%
df.iloc[0] + df.iloc[1]
# Out:
# 0    VollkornbrotEnergie       187,6 Kcal         M...
# dtype: object

# %%
df.loc[0]
# Out:
# 0    Vollkornbrot
# Name: 0, dtype: object

# %% [markdown]
# The data is stored in one frame and extended over many rows. In the next step the data is summarized from 14 rows. Afterwards the data is split in many different nutrition dataframes.

# %%
dx = pd.DataFrame()

# %%
for i in range(0, len(df.index)):
    if ((i+14)%14)==0:
        t = df.iloc[i] +" " + df.iloc[i+1] +" "+ df.iloc[i+2]+" "+ df.iloc[i+3]+" "+ df.iloc[i+4]+" "+ df.iloc[i+5]+" "+ df.iloc[i+6]+" "+ df.iloc[i+7]+" "+ df.iloc[i+8]+" "+ df.iloc[i+9]+" "+ df.iloc[i+10]+" "+ df.iloc[i+11]+" "+ df.iloc[i+12]+" "+ df.iloc[i+13]
        dx = dx.append(t, ignore_index=True)

# %%
# Länge des Dataframe:
df.shape[0]
len(df.index)
# Out:
# 15386

# %%
dx
# Out:
#                                                       0
# 0     Vollkornbrot Energie       187,6 Kcal         ...
# 1     Vollkornbrot mit Ölsamen Energie       203,6 K...
# 2     Graubrot-Toastbrot mit Schrot Energie       24...
# 3     Graubrot-Weizenmischbrot Energie       219,1 K...
# 4     Graubrot-Mehrkornbrot Energie       221,1 Kcal...
# ...                                                 ...
# 1094  Tomatensoße Energie        75,3 Kcal         M...
# 1095  Wiener Schnitzel Energie       249,0 Kcal     ...
# 1096  Wurst gemischt Energie       324,5 Kcal       ...
# 1097  Gemüsemischung roh Energie        21,2 Kcal   ...
# 1098  Fisch paniert Energie       201,6 Kcal        ...
#
# [1099 rows x 1 columns]

# %%
dx[['Lebensmittel','Energie in Kcal']]= dx[0].str.split(expand=True, pat='Energie ')

# %%
dx
# Out:
#                                                       0  \
# 0     Vollkornbrot Energie       187,6 Kcal         ...
# 1     Vollkornbrot mit Ölsamen Energie       203,6 K...
# 2     Graubrot-Toastbrot mit Schrot Energie       24...
# 3     Graubrot-Weizenmischbrot Energie       219,1 K...
# 4     Graubrot-Mehrkornbrot Energie       221,1 Kcal...
# ...                                                 ...
# 1094  Tomatensoße Energie        75,3 Kcal         M...
# 1095  Wiener Schnitzel Energie       249,0 Kcal     ...
# 1096  Wurst gemischt Energie       324,5 Kcal       ...
# 1097  Gemüsemischung roh Energie        21,2 Kcal   ...
# 1098  Fisch paniert Energie       201,6 Kcal        ...
#
#                         Lebensmittel  \
# 0                      Vollkornbrot
# 1          Vollkornbrot mit Ölsamen
# 2     Graubrot-Toastbrot mit Schrot
# 3          Graubrot-Weizenmischbrot
# 4             Graubrot-Mehrkornbrot
# ...                              ...
# 1094                    Tomatensoße
# 1095               Wiener Schnitzel
# 1096                 Wurst gemischt
# 1097             Gemüsemischung roh
# 1098                  Fisch paniert
#
#                                         Energie in Kcal
# 0           187,6 Kcal         Magnes.        57,0 m...
# 1           203,6 Kcal         Magnes.        71,0 m...
# 2           247,6 Kcal         Magnes.        48,0 m...
# 3           219,1 Kcal         Magnes.        40,0 m...
# 4           221,1 Kcal         Magnes.        45,0 m...
# ...                                                 ...
# 1094         75,3 Kcal         Magnes.        19,9 m...
# 1095        249,0 Kcal         Magnes.        24,0 m...
# 1096        324,5 Kcal         Magnes.        23,9 m...
# 1097         21,2 Kcal         Magnes.        13,4 m...
# 1098        201,6 Kcal         Magnes.        23,4 m...
#
# [1099 rows x 3 columns]

# %%
dx[['Energie in Kcal', 'Magnesium in mg']]= dx['Energie in Kcal'].str.split(expand=True, pat='Magnes.')

# %%
dx[['Magnesium in mg', 'Wasser in g']]= dx['Magnesium in mg'].str.split(expand=True, pat='Wasser')

# %%
dx[['Wasser in g', 'Calcium in mg']]= dx['Wasser in g'].str.split(expand=True, pat='Calcium')

# %%
dx[['Calcium in mg', 'Eiweiß in g']]= dx['Calcium in mg'].str.split(expand=True, pat='Eiweiß')

# %%
dx[['Eiweiß in g', 'Phosph. in mg']]= dx['Eiweiß in g'].str.split(expand=True, pat='Phosph.')

# %%
dx[['Phosph. in mg', 'Fett in g']]= dx['Phosph. in mg'].str.split(expand=True, pat='Fett')

# %%
dx[['Fett in g', 'Eisen in mg']]= dx['Fett in g'].str.split(expand=True, pat='Eisen')

# %%
dx[['Eisen in mg', 'KH in g']]= dx['Eisen in mg'].str.split(expand=True, pat='KH')

# %%
dx[['KH in g','Zink in mg']]= dx['KH in g'].str.split(expand=True, pat='Zink')

# %%
dx[['Zink in mg', 'ung. FS in g']]= dx['Zink in mg'].str.split(expand=True, pat='ung. FS')

# %%
dx[['ung. FS in g', 'Vit. A in µg']]= dx['ung. FS in g'].str.split(expand=True, pat='Vit. A.')

# %%
dx[['Vit. A in µg', 'Chol. in mg']]= dx['Vit. A in µg'].str.split(expand=True, pat='Chol.')

# %%
dx[['Chol. in mg', 'Carotin in mg']]= dx['Chol. in mg'].str.split(expand=True, pat='Carotin')

# %%
dx[['Carotin in mg','Alkohol in g']]= dx['Carotin in mg'].str.split(expand=True, pat='Alkohol')

# %%
dx[['Alkohol in g', 'Vit. E in mg']]= dx['Alkohol in g'].str.split(expand=True, pat='Vit. E')

# %%
dx[['Vit. E in mg','Harnsr. in mg']]= dx['Vit. E in mg'].str.split(expand=True, pat='Harnsr.')

# %%
dx[['Harnsr. in mg', 'Fols. in µg']]= dx['Harnsr. in mg'].str.split(expand=True, pat='Fols.')

# %%
dx[['Fols. in µg', 'tie. EW in g']]= dx['Fols. in µg'].str.split(expand=True, pat='tie. EW')

# %%
dx[['tie. EW in g', 'Vit. B1 in mg']]= dx['tie. EW in g'].str.split(expand=True, pat='Vit. B1')

# %%
dx[['Vit. B1 in mg', 'BST in g']]= dx['Vit. B1 in mg'].str.split(expand=True, pat='BST')

# %%
dx[['BST in g', 'Vit. B2 in mg']]= dx['BST in g'].str.split(expand=True, pat='Vit. B2')

# %%
dx[['Vit. B2 in mg', 'Natrium in mg']]= dx['Vit. B2 in mg'].str.split(expand=True, pat='Natrium')

# %%
dx[['Natrium in mg', 'Vit. B6 in mg']]= dx['Natrium in mg'].str.split(expand=True, pat='Vit. B6')

# %%
dx[['Vit. B6 in mg', 'Kalium in mg']]= dx['Vit. B6 in mg'].str.split(expand=True, pat='Kalium')

# %%
dx[['Kalium in mg', 'Vit. C in mg']]= dx['Kalium in mg'].str.split(expand=True, pat='Vit. C')

# %%
dx
# Out:
#                                                       0  \
# 0     Vollkornbrot Energie       187,6 Kcal         ...
# 1     Vollkornbrot mit Ölsamen Energie       203,6 K...
# 2     Graubrot-Toastbrot mit Schrot Energie       24...
# 3     Graubrot-Weizenmischbrot Energie       219,1 K...
# 4     Graubrot-Mehrkornbrot Energie       221,1 Kcal...
# ...                                                 ...
# 1094  Tomatensoße Energie        75,3 Kcal         M...
# 1095  Wiener Schnitzel Energie       249,0 Kcal     ...
# 1096  Wurst gemischt Energie       324,5 Kcal       ...
# 1097  Gemüsemischung roh Energie        21,2 Kcal   ...
# 1098  Fisch paniert Energie       201,6 Kcal        ...
#
#                         Lebensmittel            Energie in Kcal  \
# 0                      Vollkornbrot         187,6 Kcal
# 1          Vollkornbrot mit Ölsamen         203,6 Kcal
# 2     Graubrot-Toastbrot mit Schrot         247,6 Kcal
# 3          Graubrot-Weizenmischbrot         219,1 Kcal
# 4             Graubrot-Mehrkornbrot         221,1 Kcal
# ...                              ...                        ...
# 1094                    Tomatensoße          75,3 Kcal
# 1095               Wiener Schnitzel         249,0 Kcal
# 1096                 Wurst gemischt         324,5 Kcal
# 1097             Gemüsemischung roh          21,2 Kcal
# 1098                  Fisch paniert         201,6 Kcal
#
#        Magnesium in mg                  Wasser in g     Calcium in mg  \
# 0             57,0 mg            44,0  g                     22,0 mg
# 1             71,0 mg            42,4  g                     25,0 mg
# 2             48,0 mg            35,7  g                     41,0 mg
# 3             40,0 mg            41,0  g                     22,0 mg
# 4             45,0 mg            40,2  g                     25,0 mg
# ...                ...                          ...               ...
# 1094          19,9 mg            83,5  g                     20,3 mg
# 1095          24,0 mg            59,7  g                      8,5 mg
# 1096          23,9 mg            51,9  g                     19,9 mg
# 1097          13,4 mg            92,3  g                     20,1 mg
# 1098          23,4 mg            58,2  g                     27,1 mg
#
#                       Eiweiß in g     Phosph. in mg  \
# 0               6,5  g                    232,0 mg
# 1               7,1  g                    248,0 mg
# 2               7,2  g                    181,0 mg
# 3               7,1  g                    130,0 mg
# 4               6,1  g                    142,0 mg
# ...                           ...               ...
# 1094            1,6  g                     33,9 mg
# 1095           17,3  g                    171,2 mg
# 1096           15,6  g                    231,9 mg
# 1097            1,0  g                     28,1 mg
# 1098           16,8  g                    167,1 mg
#
#                           Fett in g         Eisen in mg  ...  \
# 0                 1,0  g                        2,7 mg   ...
# 1                 3,0  g                        2,8 mg   ...
# 2                 3,5  g                        2,2 mg   ...
# 3                 0,9  g                        1,7 mg   ...
# 4                 1,0  g                        1,9 mg   ...
# ...                             ...                 ...  ...
# 1094              4,4  g                        0,7 mg   ...
# 1095             15,4  g                        1,5 mg   ...
# 1096             28,8  g                        3,0 mg   ...
# 1097              0,3  g                        0,8 mg   ...
# 1098              8,7  g                        0,8 mg   ...
#
#                    Harnsr. in mg         Fols. in µg  \
# 0             57,0 mg                       15,0 µg
# 1             61,0 mg                       17,0 µg
# 2             74,0 mg                       22,0 µg
# 3             49,0 mg                       12,0 µg
# 4             53,0 mg                       13,0 µg
# ...                          ...                 ...
# 1094          13,6 mg                        5,9 µg
# 1095         118,5 mg                        4,7 µg
# 1096         124,0 mg                        5,7 µg
# 1097          11,5 mg                       18,1 µg
# 1098         130,6 mg                       10,4 µg
#
#                     tie. EW in g     Vit. B1 in mg  \
# 0              0,0  g                      0,1 mg
# 1              0,0  g                      0,2 mg
# 2              0,5  g                      0,2 mg
# 3              0,0  g                      0,2 mg
# 4              0,0  g                      0,2 mg
# ...                          ...               ...
# 1094           0,0  g                      0,0 mg
# 1095          16,4  g                      0,7 mg
# 1096          15,4  g                      0,5 mg
# 1097           0,0  g                      0,0 mg
# 1098          14,9  g                      0,1 mg
#
#                             BST in g     Vit. B2 in mg  \
# 0                  8,5  g                      0,1 mg
# 1                  8,4  g                      0,1 mg
# 2                  4,9  g                      0,2 mg
# 3                  3,9  g                      0,1 mg
# 4                  4,7  g                      0,1 mg
# ...                              ...               ...
# 1094               2,3  g                      0,0 mg
# 1095               0,4  g                      0,2 mg
# 1096               0,1  g                      0,3 mg
# 1097               2,0  g                      0,1 mg
# 1098               1,0  g                      0,1 mg
#
#                    Natrium in mg     Vit. B6 in mg  \
# 0            562,0 mg                      0,2 mg
# 1            539,0 mg                      0,2 mg
# 2            507,0 mg                      0,2 mg
# 3            508,0 mg                      0,1 mg
# 4            417,0 mg                      0,2 mg
# ...                          ...               ...
# 1094         338,8 mg                      0,1 mg
# 1095          93,0 mg                      0,4 mg
# 1096         914,7 mg                      0,3 mg
# 1097          17,1 mg                      0,1 mg
# 1098         154,3 mg                      0,2 mg
#
#                      Kalium in mg        Vit. C in mg
# 0             289,0 mg                       0,0 mg
# 1             306,0 mg                       0,0 mg
# 2             240,0 mg                       0,1 mg
# 3             157,0 mg                       0,0 mg
# 4             176,0 mg                       0,0 mg
# ...                           ...                 ...
# 1094          346,8 mg                      12,7 mg
# 1095          324,4 mg                       0,0 mg
# 1096          293,7 mg                      13,1 mg
# 1097          242,9 mg                      39,6 mg
# 1098          242,8 mg                       0,4 mg
#
# [1099 rows x 28 columns]

# %% [markdown]
# The complete dataset has a unncessary frame '0' that needs to be removed. Moreover the units in the rows are removed.

# %%
dx.drop(columns=[0], inplace=True)

# %%
#dx.to_csv('Lebensmitteltabelle.csv', index=False)

# %%
dx['Energie in Kcal']=dx['Energie in Kcal'].str.replace('Kcal','')

# %%
dx['Magnesium in mg']=dx['Magnesium in mg'].str.replace('mg','')

# %%
dx['Wasser in g']=dx['Wasser in g'].str.replace('g','')

# %%
dx['Calcium in mg']=dx['Calcium in mg'].str.replace('mg','')

# %%
dx['Eiweiß in g']=dx['Eiweiß in g'].str.replace('g','')

# %%
dx['Phosph. in mg']=dx['Phosph. in mg'].str.replace('mg','')

# %%
dx['Fett in g']=dx['Fett in g'].str.replace('g','')

# %%
dx['Eisen in mg']=dx['Eisen in mg'].str.replace('mg','')

# %%
dx['KH in g']=dx['KH in g'].str.replace('g','')

# %%
dx['Zink in mg']=dx['Zink in mg'].str.replace('mg','')

# %%
dx['ung. FS in g']=dx['ung. FS in g'].str.replace('g','')

# %%
dx['Vit. A in µg']=dx['Vit. A in µg'].str.replace('µg','')

# %%
dx['Chol. in mg']=dx['Chol. in mg'].str.replace('mg','')

# %%
dx['Carotin in mg']=dx['Carotin in mg'].str.replace('mg','')

# %%
dx['Alkohol in g']=dx['Alkohol in g'].str.replace('g','')

# %%
dx['Vit. E in mg']=dx['Vit. E in mg'].str.replace('mg','')

# %%
dx['Harnsr. in mg']=dx['Harnsr. in mg'].str.replace('mg','')

# %%
dx['Fols. in µg']=dx['Fols. in µg'].str.replace('µg','')

# %%
dx['tie. EW in g']=dx['tie. EW in g'].str.replace('g','')

# %%
dx['Vit. B1 in mg']=dx['Vit. B1 in mg'].str.replace('mg','')

# %%
dx['BST in g']=dx['BST in g'].str.replace('g','')

# %%
dx['Vit. B2 in mg']=dx['Vit. B2 in mg'].str.replace('mg','')

# %%
dx['Natrium in mg']=dx['Natrium in mg'].str.replace('mg','')

# %%
dx['Vit. B6 in mg']=dx['Vit. B6 in mg'].str.replace('mg','')

# %%
dx['Kalium in mg']=dx['Kalium in mg'].str.replace('mg','')

# %%
dx['Vit. C in mg']=dx['Vit. C in mg'].str.replace('mg','')

# %% [markdown]
# Finally the cleaned dataset is stored in a csv file

# %%
dx.to_csv('Lebensmitteltabelle.csv', index=False)
